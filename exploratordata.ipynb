# %%
import pandas as pd 
import matplotlib as plt

# %%
df = pd.DataFrame()

# %%
df = pd.read_excel('COVIDDATA.xlsx')

# %%
df
# Out:
#        iso_code continent      country       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 155182      ZWE    Africa     Zimbabwe 2022-01-12     224433.0     1433.0
# 155183      ZWE    Africa     Zimbabwe 2022-01-13     225084.0      651.0
# 155184      ZWE    Africa     Zimbabwe 2022-01-14     225637.0      553.0
# 155185      ZWE    Africa     Zimbabwe 2022-01-15     225637.0        0.0
# 155186      ZWE    Africa     Zimbabwe 2022-01-16     226078.0      441.0
#
#         total_deaths  new_deaths  total_cases_per_million  \
# ...

# %% [markdown]
# Creating Smaller Dataframes to distribute and analize contextual data
# Given data set
# Italy, Portugal, UK, Mexico and Canada

# %% [markdown]
# This is for distribution of Data with members

# %%
portugal = df[(df['country']=='Portugal')]

# %%
portugal.to_csv('PortugalDATA.csv')

# %%
Canada = df[df['country']=='Canada']

# %%
Canada.to_csv('CanadaDATA.csv')

# %%
Italy  = df[df['country']=='Italy']

# %%
Italy.to_csv('ItalyDATA.csv')

# %%
UnitedKingdom = df[df['country']=='United Kingdom']

# %%
UnitedKingdom.to_csv('UnitedKingdomDATA.csv')

# %%
Mexico = df[df['country']=='Mexico']

# %%
Mexico.to_csv('MexicoDATA.csv')

# %%
Portugal = df[df['country']=='Portugal']

# %%
Portugal.to_csv('Portugal.csv')
